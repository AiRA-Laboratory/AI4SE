# %% [markdown]
# # 01 — Variational Autoencoder (VAE)
#
# **Module 2 · Week 3 · TA-2**
#
# This notebook covers:
# - Encoder: mapping data to latent distribution
# - Reparameterization trick
# - Decoder: mapping latent to reconstruction
# - VAE loss = reconstruction loss + KL divergence
# - Latent space visualization
# - Generating new samples
#
# ---

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
LATENT_DIM = 2  # 2D for easy visualization
print(f'Device: {device}')

# %% [markdown]
# ## 1. Dataset

# %%
transform = transforms.Compose([transforms.ToTensor()])
train_data = torchvision.datasets.MNIST('./data', train=True, download=True, transform=transform)
val_data = torchvision.datasets.MNIST('./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
val_loader = DataLoader(val_data, batch_size=512, shuffle=False)
print(f'Input shape: {train_data[0][0].shape}')  # (1, 28, 28)

# %% [markdown]
# ## 2. Define VAE

# %%
class VAE(nn.Module):
    def __init__(self, latent_dim: int = 2):
        super().__init__()
        self.latent_dim = latent_dim

        # --- TODO: Encoder ---
        # Input: flattened 784
        # Hidden layers: 512, 256
        # Output heads: mu (latent_dim) and log_var (latent_dim)
        self.encoder = None  # replace with nn.Sequential
        self.fc_mu = None
        self.fc_logvar = None

        # --- TODO: Decoder ---
        # Input: latent_dim
        # Hidden layers: 256, 512
        # Output: 784 (sigmoid activation — output in [0,1])
        self.decoder = None  # replace with nn.Sequential

    def encode(self, x):
        x = x.view(x.size(0), -1)  # flatten
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        # --- TODO: Implement reparameterization trick ---
        # z = mu + eps * std, where eps ~ N(0,I)
        pass

    def decode(self, z):
        return self.decoder(z).view(-1, 1, 28, 28)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        x_recon = self.decode(z)
        return x_recon, mu, logvar


model = VAE(latent_dim=LATENT_DIM).to(device)
print(model)

# %% [markdown]
# ## 3. VAE Loss Function

# %%
def vae_loss(x_recon, x, mu, logvar, beta=1.0):
    # --- TODO: Implement VAE loss ---
    # reconstruction_loss = BCE(x_recon, x) averaged over batch
    # kl_loss = -0.5 * mean(1 + logvar - mu^2 - exp(logvar))
    # return total_loss, reconstruction_loss, kl_loss
    pass

# %% [markdown]
# ## 4. Training Loop

# %%
# --- TODO: Training loop ---
# Optimizer: Adam(lr=1e-3)
# Train for 10 epochs
# Log reconstruction loss and KL loss separately

# %% [markdown]
# ## 5. Visualize Reconstructions

# %%
# --- TODO: Show original vs reconstructed for 8 samples ---

# %% [markdown]
# ## 6. Latent Space Visualization

# %%
# --- TODO: Scatter plot of 2D latent space, colored by digit label ---
# Encode all val images, plot mu colored by label

# %% [markdown]
# ## 7. Latent Interpolation

# %%
# --- TODO: Interpolate between two latent points ---
# 1. Pick two val images from different classes
# 2. Encode both to get z1, z2
# 3. Interpolate: z_interp = (1-alpha)*z1 + alpha*z2 for alpha in [0,1]
# 4. Decode each interpolation step and plot

# %% [markdown]
# ## 8. Generate New Samples

# %%
# --- TODO: Sample z ~ N(0,I) and decode ---
# Show a 4x4 grid of generated samples
