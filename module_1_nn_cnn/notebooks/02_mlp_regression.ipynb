# %% [markdown]
# # 02 — MLP for Scientific Regression
#
# **Module 1 · Week 1 · TA-1**
#
# This notebook covers:
# - Building an MLP with `nn.Sequential`
# - Standard train/val split and DataLoader
# - Full training loop
# - Plotting loss curves and predictions
#
# ---

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
import matplotlib.pyplot as plt
import numpy as np

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

# %% [markdown]
# ## 1. Generate Dataset (Toy Scientific Problem)

# %%
# Predict heat flux Q = h * A * (T_surface - T_fluid)
# Features: [h (convection coeff), A (area), delta_T (temperature diff)]
# Target: Q (heat flux)

N = 2000
h = torch.rand(N, 1) * 100 + 10         # W/(m^2 K), range [10, 110]
A = torch.rand(N, 1) * 0.5 + 0.01       # m^2
delta_T = torch.rand(N, 1) * 80 + 5     # K

X = torch.cat([h, A, delta_T], dim=1)   # shape (N, 3)
y = h * A * delta_T                     # shape (N, 1)

# Add noise
y = y + 0.02 * y * torch.randn_like(y)

print(f'X shape: {X.shape}, y shape: {y.shape}')
print(f'y range: [{y.min():.1f}, {y.max():.1f}]')

# %% [markdown]
# ## 2. Data Preprocessing and DataLoader

# %%
# --- TODO: Normalize X and y ---
# 1. Compute mean and std of X (per feature) and y
# 2. Normalize: X_norm = (X - mean) / std
# 3. Create TensorDataset
# 4. Split into train (80%) and val (20%) using random_split
# 5. Create DataLoader with batch_size=64

# %% [markdown]
# ## 3. Define MLP Model

# %%
# --- TODO: Define MLP ---
# Requirements:
# - Input: 3 features
# - At least 2 hidden layers
# - ReLU activations
# - Output: 1 (regression)

class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        # TODO: define layers
        pass

    def forward(self, x):
        # TODO: implement forward pass
        pass

model = MLP().to(device)
print(model)

# %% [markdown]
# ## 4. Training Loop

# %%
# --- TODO: Training loop ---
# 1. Define MSELoss and Adam optimizer (lr=1e-3)
# 2. Train for 100 epochs
# 3. For each epoch: compute train loss and val loss
# 4. Store losses in lists
# 5. Print loss every 10 epochs

# %% [markdown]
# ## 5. Plot Loss Curves

# %%
# --- TODO: Plot train and val loss over epochs ---
# Use plt.semilogy for log scale if loss range is large

# %% [markdown]
# ## 6. Evaluate: Predicted vs True

# %%
# --- TODO: Scatter plot of predicted vs true on validation set ---
# Add a y=x diagonal line for reference
# Report MSE and MAE

# %% [markdown]
# ## 7. Reflection
#
# *(Complete this section as part of your Week 1 assignment)*
#
# **Q1: Does your model overfit? How can you tell?**
#
# ...
#
# **Q2: What happens when you change the learning rate?**
#
# ...
#
# **Q3: What happens when you add or remove a hidden layer?**
#
# ...
