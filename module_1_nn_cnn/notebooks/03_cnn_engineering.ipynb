# %% [markdown]
# # 03 — CNN for Engineering Data
#
# **Module 1 · Week 2 · TA-1**
#
# This notebook covers:
# - Building a CNN classifier/regressor
# - Working with image-like 2D engineering data
# - DataLoader with transforms
# - Feature map visualization
# - Comparing CNN vs MLP
#
# ---

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from torchinfo import summary

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

# %% [markdown]
# ## 1. Load Dataset

# %%
# Using MNIST as a stand-in for "sensor map" or "field map" data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, download=True, transform=transform)
val_dataset = torchvision.datasets.MNIST(
    root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)

print(f'Training samples: {len(train_dataset)}')
print(f'Validation samples: {len(val_dataset)}')
print(f'Image shape: {train_dataset[0][0].shape}')  # (1, 28, 28)

# %% [markdown]
# ## 2. Visualize Some Samples

# %%
# --- TODO: Plot a 4x4 grid of training images with labels ---

# %% [markdown]
# ## 3. Define CNN

# %%
# --- TODO: Define CNN ---
# Architecture suggestion:
# Conv2d(1, 32, 3, padding=1) -> BatchNorm -> ReLU -> MaxPool(2)
# Conv2d(32, 64, 3, padding=1) -> BatchNorm -> ReLU -> MaxPool(2)
# Flatten -> Linear(64*7*7, 128) -> ReLU -> Linear(128, 10)

class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        # TODO
        pass

    def forward(self, x):
        # TODO
        pass

model = CNN().to(device)
summary(model, input_size=(1, 1, 28, 28))

# %% [markdown]
# ## 4. Training Loop

# %%
# --- TODO: Training loop ---
# Loss: nn.CrossEntropyLoss()
# Optimizer: Adam(lr=1e-3)
# Train for 5 epochs
# Log: train loss, val loss, val accuracy per epoch

# %% [markdown]
# ## 5. Visualize Feature Maps

# %%
# --- TODO: Visualize first-layer feature maps for one test image ---
# 1. Forward one image through the first conv layer
# 2. Plot each of the 32 feature maps as a subplot

# %% [markdown]
# ## 6. Compare with MLP

# %%
# --- TODO: Define and train a flat MLP on the same data ---
# MLP input: flatten 28x28 = 784
# Compare val accuracy and parameter count

# Fill in the comparison table:
# | Model | Val Accuracy | # Parameters | Training Time |
# |-------|------------|--------------|---------------|
# | MLP   |            |              |               |
# | CNN   |            |              |               |
