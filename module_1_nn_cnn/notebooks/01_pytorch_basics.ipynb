# %% [markdown]
# # 01 — PyTorch Basics
#
# **Module 1 · Week 1 · TA-1**
#
# This notebook covers:
# - Tensors: creation, indexing, operations
# - GPU vs CPU
# - Autograd: computing gradients
# - Simple linear regression with autograd
#
# ---

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# %% [markdown]
# ## 1. Tensors

# %%
# --- TODO: Create tensors and explore operations ---
# 1. Create a 3x4 tensor of zeros
# 2. Create a 3x4 tensor of random values
# 3. Add them together
# 4. Print the shape, dtype, and device

# %% [markdown]
# ## 2. Autograd

# %%
# --- TODO: Autograd basics ---
# 1. Create x = tensor([2.0]) with requires_grad=True
# 2. Compute y = x**2 + 3*x + 1
# 3. Call y.backward()
# 4. Print x.grad — should be dy/dx = 2x + 3 = 7 at x=2

# %% [markdown]
# ## 3. Simple Linear Regression with Gradient Descent

# %%
# Generate toy data: y = 2x + 1 + noise
torch.manual_seed(42)
X = torch.linspace(-1, 1, 100).reshape(-1, 1)
y = 2 * X + 1 + 0.1 * torch.randn_like(X)

# --- TODO: Implement linear regression ---
# 1. Define a linear model: nn.Linear(1, 1)
# 2. Define MSE loss: nn.MSELoss()
# 3. Define SGD optimizer
# 4. Training loop: 200 epochs
# 5. Print loss every 50 epochs
# 6. Print learned weight and bias — should be close to [2, 1]

# %% [markdown]
# ## 4. Plot Results

# %%
# --- TODO: Plot predictions vs true values ---
